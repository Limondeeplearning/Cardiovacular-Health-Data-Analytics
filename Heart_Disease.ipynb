# %% [markdown]
# # Cardiovacular Health Data Analytics
# ---
# ### This project delves in the world of individual health profiles, specifically focusing on the subsets of male and female 49 below and 50 and above this analytic project aims to discern the relationship trends within key indicators such as stystolic blood presssure (trestbps) and cholesterol level (chol)
#
# ### Dataset: https://www.kaggle.com/datasets/johnsmith88/heart-disease-dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reminder
#
# #### Sex = (M = 1 | F = 0)

# %%
heart = pd.read_csv('heart.csv', usecols=['age', 'sex', 'trestbps', 'chol'])
heart.head(5)
# Out:
#    age  sex  trestbps  chol
# 0   52    1       125   212
# 1   53    1       140   203
# 2   70    1       145   174
# 3   61    1       148   203
# 4   62    0       138   294

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   trestbps  1025 non-null   int64
#  3   chol      1025 non-null   int64
# dtypes: int64(4)
# memory usage: 32.2 KB

# %%
heart.describe().round(2)
# Out:
#            age      sex  trestbps     chol
# count  1025.00  1025.00   1025.00  1025.00
# mean     54.43     0.70    131.61   246.00
# std       9.07     0.46     17.52    51.59
# min      29.00     0.00     94.00   126.00
# 25%      48.00     0.00    120.00   211.00
# 50%      56.00     1.00    130.00   240.00
# 75%      61.00     1.00    140.00   275.00
# max      77.00     1.00    200.00   564.00

# %% [markdown]
# ### Split the whole data frame into Males and Females

# %%
male_data = heart[heart['sex'] == 1]
female_data = heart[heart['sex'] == 0]

# %% [markdown]
# # Male Data Analysis

# %%
male_data.describe()
# Out:
#               age    sex    trestbps        chol
# count  713.000000  713.0  713.000000  713.000000
# mean    53.814867    1.0  130.697055  239.237027
# std      8.875668    0.0   16.463723   43.155535
# min     29.000000    1.0   94.000000  126.000000
# 25%     47.000000    1.0  120.000000  208.000000
# 50%     55.000000    1.0  130.000000  234.000000
# 75%     60.000000    1.0  140.000000  269.000000
# max     77.000000    1.0  192.000000  353.000000

# %%
male_data.describe().loc[['min', 'mean','max']].round(2)
# Out:
#         age  sex  trestbps    chol
# min   29.00  1.0      94.0  126.00
# mean  53.81  1.0     130.7  239.24
# max   77.00  1.0     192.0  353.00

# %% [markdown]
# ---
# ### Split the data into two age bracket 49 below and 50 and above

# %%
male_data_49_below = male_data[male_data['age'] < 50 ]
male_data_50_above = male_data[male_data['age'] >= 50 ]

# %% [markdown]
# ### Males 49 and Below

# %%
male_data_49_below.describe().round(2)
# Out:
#           age    sex  trestbps    chol
# count  218.00  218.0    218.00  218.00
# mean    42.86    1.0    124.77  231.40
# std      4.21    0.0     11.89   43.45
# min     29.00    1.0    101.00  149.00
# 25%     41.00    1.0    118.00  198.00
# 50%     43.00    1.0    122.00  231.00
# 75%     46.00    1.0    130.00  256.00
# max     49.00    1.0    152.00  321.00

# %%
selected_columns = ['trestbps', 'chol']

# %%
min_mean_max = male_data_49_below[selected_columns].agg(['min', 'mean', 'max']).round(2)
min_mean_max
# Out:
#       trestbps   chol
# min     101.00  149.0
# mean    124.77  231.4
# max     152.00  321.0

# %% [markdown]
# ### Males 50 and above

# %%
male_data_50_above.describe().round(3)
# Out:
#            age    sex  trestbps     chol
# count  495.000  495.0   495.000  495.000
# mean    58.638    1.0   133.309  242.687
# std      5.432    0.0    17.498   42.613
# min     50.000    1.0    94.000  126.000
# 25%     54.000    1.0   120.000  212.000
# 50%     58.000    1.0   130.000  237.000
# 75%     62.000    1.0   142.000  273.500
# max     77.000    1.0   192.000  353.000

# %%
male_data_50_above.describe().loc[['min', 'mean', 'max']].round(2)
# Out:
#         age  sex  trestbps    chol
# min   50.00  1.0     94.00  126.00
# mean  58.64  1.0    133.31  242.69
# max   77.00  1.0    192.00  353.00

# %% [markdown]
# # Female Data Analysis

# %%
female_data.describe().round(2)
# Out:
#           age    sex  trestbps    chol
# count  312.00  312.0    312.00  312.00
# mean    55.85    0.0    133.70  261.46
# std      9.37    0.0     19.58   64.47
# min     34.00    0.0     94.00  141.00
# 25%     50.00    0.0    120.00  215.00
# 50%     57.00    0.0    132.00  254.00
# 75%     63.00    0.0    140.00  302.00
# max     76.00    0.0    200.00  564.00

# %%
female_data.describe().loc[['min', 'mean', 'max']].round(2)
# Out:
#         age  sex  trestbps    chol
# min   34.00  0.0      94.0  141.00
# mean  55.85  0.0     133.7  261.46
# max   76.00  0.0     200.0  564.00

# %%
female_data_49_below = female_data[female_data['age'] < 50 ]
female_data_50_above = female_data[female_data['age'] >= 50 ]

# %% [markdown]
# #### Female 49 and below

# %%
female_data_49_below.describe().round(2)
# Out:
#          age   sex  trestbps    chol
# count  76.00  76.0     76.00   76.00
# mean   42.59   0.0    123.21  229.30
# std     3.96   0.0     13.15   46.41
# min    34.00   0.0     94.00  141.00
# 25%    41.00   0.0    112.00  202.75
# 50%    43.00   0.0    126.00  220.00
# 75%    45.00   0.0    134.00  265.75
# max    49.00   0.0    142.00  341.00

# %%
female_data_49_below.describe().loc[['min', 'mean', 'max']].round(2)
# Out:
#         age  sex  trestbps   chol
# min   34.00  0.0     94.00  141.0
# mean  42.59  0.0    123.21  229.3
# max   49.00  0.0    142.00  341.0

# %%
female_data_50_above.describe().round(2)
# Out:
#           age    sex  trestbps    chol
# count  236.00  236.0    236.00  236.00
# mean    60.12    0.0    137.08  271.81
# std      6.00    0.0     20.13   66.11
# min     50.00    0.0    100.00  149.00
# 25%     55.00    0.0    124.00  225.00
# 50%     60.00    0.0    135.00  265.00
# 75%     64.00    0.0    150.00  305.00
# max     76.00    0.0    200.00  564.00

# %%
female_data_50_above.describe().loc[['min', 'mean', 'max']].round(2)
# Out:
#         age  sex  trestbps    chol
# min   50.00  0.0    100.00  149.00
# mean  60.12  0.0    137.08  271.81
# max   76.00  0.0    200.00  564.00
